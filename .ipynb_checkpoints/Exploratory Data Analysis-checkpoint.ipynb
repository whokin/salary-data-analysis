# %% [markdown]
# # Objective

# %% [markdown]
# The input data of the project is self reported salaries collected by @chrristen on TikTok. The data snapshot dates from February 19, 2020.
#
# ### Phase 1: EDA
# The objective of this first phase is to explore the data, find patterns and identity pre-processing needs.

# %% [markdown]
# # Environment variables

# %%
path_root = "C:/Git/salary-data-analysis/"
path_data = f"{path_root}data/"
path_output = f"{path_root}output/"

# %% [markdown]
# # Import libraries

# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Data

# %%
df_salary: pd.DataFrame = pd.read_csv(f"{path_data}anonymous_salary_survey.csv")

# %%
df_salary.head()
# Out:
#             Timestamp Age Range Years of Experience                 Industry  \
# 0  12/5/2021 11:57:44     26-29                   6               Healthcare
# 1  12/6/2021 19:31:12     30-33                  13           Retail banking
# 2  12/6/2021 19:32:36     22-25                   1                  fintech
# 3  12/6/2021 19:34:44     22-25                   2  Marketing/Data/Business
# 4  12/6/2021 19:39:18     22-25                   1                   Retail
#
#                            Job Title     Company Name  \
# 0                   Registered Nurse    Penn Medicine
# 1           Financial center manager  Bank of America
# 2                               SDR               NaN
# 3  Associate Business System Analyst          Epsilon
# 4                 Software Engineer            Target
#
#   Highest Level of Education Received  \
# 0                   Bachelor's Degree
# 1      Some College credit, no degree
# 2                   Bachelor's Degree
# ...

# %%
df_salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62080 entries, 0 to 62079
# Data columns (total 22 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Timestamp                                                              62080 non-null  object
#  1   Age Range                                                              60677 non-null  object
#  2   Years of Experience                                                    60524 non-null  object
#  3   Industry                                                               59430 non-null  object
#  4   Job Title                                                              59442 non-null  object
#  5   Company Name                                                           35468 non-null  object
# ...
